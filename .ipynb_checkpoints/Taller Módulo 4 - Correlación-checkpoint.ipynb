# %%
# Importar librerias
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")
import seaborn as sns
from scipy import stats

data = pd.read_csv('mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# Matriz de Correlaciones
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# De la matriz de correlación obervamos que las variables "displacement" y "weight" tienen un coeficiente de correlación de 0.93, lo que indica una corelación lineal fuerte positiva.
#
# A contunuación se realizará el análisis de correlación paso a paso.

# %%
#Gráfico de dispersión:
sns.scatterplot(data=data, x='displacement', y='weight')
plt.grid()
plt.show()

# %% [markdown]
# Del gráfico de dispersión se observa una tendencia a una relación lineal positiva (cuando una de las varaibles aumenta, la otra también aumenta).

# %%
# Normalidad
fig, axs = plt.subplots(1,2, figsize=(10, 4))

axs[0].hist(x=data.displacement, bins=20, alpha=0.5)
axs[0].set_title('Distribución Kilometraje (displacement)')
axs[0].set_xlabel('displacement')
axs[0].set_ylabel('frecuencia')

axs[1].hist(x=data.weight, bins=20, alpha=0.5)
axs[1].set_title('Distribución Peso (weight)')
axs[1].set_xlabel('weight')
axs[1].set_ylabel('frecuencia')

plt.show()

# %% [markdown]
# De los histogramas se observa que ninguna de las varaibles presenta una distribución normal, aunque sí se logra notar una leve tendencia a formar una campana de gauss.
#
# Dado que no se cumple con la coindición de normalidad, se procede a calcular el coeficiente de correlación de Spearman.

# %%
# Cálculo de correlación y significancia con Scipy
r, p = stats.spearmanr(data['displacement'], data['weight'])
print(f"Correlación Spearman: r={r}, p-value={p}")
# Out:
# Correlación Spearman: r=0.9459855641801795, p-value=8.192161198904985e-196

# %% [markdown]
# Los test estadísticos muestran una correlación lineal alta, con claras evidencias estadísticas de que la relación observada no se debe al azar ( pvalue≈0 ).

# %% [markdown]
# Del análisis anterior podemos notar entonces que la correlación entre el peso del vehículo y su kilometraje es alta, lo que nos daría a pensar que una variable podría ser la causante de la otra, cuando en la práctica no es así, dado que un vehículo de mayor peso no necesariamente tendrá mayor kilometraje, ni viceversa.
#
# Por lo anterior es importante entender que la correlación entre variables NO implica necesariamente causalidad.
